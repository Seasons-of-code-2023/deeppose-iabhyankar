# %% [markdown]
# Libraries

# %%
pip install deeplake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deeplake
#   Downloading deeplake-3.6.4.tar.gz (514 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.9/514.9 kB 9.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deeplake) (1.22.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from deeplake) (8.4.0)
# Collecting boto3 (from deeplake)
#   Downloading boto3-1.26.155-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from deeplake) (8.1.3)
# Collecting pathos (from deeplake)
#   Downloading pathos-0.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 6.1 MB/s eta 0:00:00
# Collecting humbug>=0.3.1 (from deeplake)
#   Downloading humbug-0.3.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from deeplake) (4.65.0)
# Collecting numcodecs (from deeplake)
#   Downloading numcodecs-0.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 51.5 MB/s eta 0:00:00
# Collecting pyjwt (from deeplake)
#   Downloading PyJWT-2.7.0-py3-none-any.whl (22 kB)
# Collecting aioboto3>=10.4.0 (from deeplake)
#   Downloading aioboto3-11.2.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from deeplake) (1.5.6)
# Collecting aiobotocore[boto3]==2.5.0 (from aioboto3>=10.4.0->deeplake)
#   Downloading aiobotocore-2.5.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 kB 6.4 MB/s eta 0:00:00
# Collecting botocore<1.29.77,>=1.29.76 (from aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake)
#   Downloading botocore-1.29.76-py3-none-any.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 86.6 MB/s eta 0:00:00
# Collecting aiohttp>=3.3.1 (from aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.5 MB/s eta 0:00:00
# Requirement already satisfied: wrapt>=1.10.10 in /usr/local/lib/python3.10/dist-packages (from aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (1.14.1)
# Collecting aioitertools>=0.5.1 (from aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake)
#   Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Collecting boto3 (from deeplake)
#   Downloading boto3-1.26.76-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 14.5 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->deeplake)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3->deeplake)
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from humbug>=0.3.1->deeplake) (2.27.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from numcodecs->deeplake) (0.4)
# Collecting ppft>=1.7.6.6 (from pathos->deeplake)
#   Downloading ppft-1.7.6.6-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.4 MB/s eta 0:00:00
# Collecting dill>=0.3.6 (from pathos->deeplake)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 11.5 MB/s eta 0:00:00
# Collecting pox>=0.3.2 (from pathos->deeplake)
#   Downloading pox-0.3.2-py3-none-any.whl (29 kB)
# Collecting multiprocess>=0.70.14 (from pathos->deeplake)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.29.77,>=1.29.76->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.29.77,>=1.29.76->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->humbug>=0.3.1->deeplake) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->humbug>=0.3.1->deeplake) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->humbug>=0.3.1->deeplake) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.3.1->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.3.1->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 9.1 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp>=3.3.1->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp>=3.3.1->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 25.3 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.3.1->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 17.0 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp>=3.3.1->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.29.77,>=1.29.76->aiobotocore[boto3]==2.5.0->aioboto3>=10.4.0->deeplake) (1.16.0)
# Building wheels for collected packages: deeplake
#   Building wheel for deeplake (setup.py) ... done
#   Created wheel for deeplake: filename=deeplake-3.6.4-py3-none-any.whl size=627716 sha256=aa99eb0f0bc02a0e57bffede1fe5547345f72a30f458486caf57e8441b260182
#   Stored in directory: /root/.cache/pip/wheels/4f/91/4b/5ad24694ad0ae17cd91a956c01ebda7ec11289e9ecdf79ab45
# Successfully built deeplake
# Installing collected packages: pyjwt, ppft, pox, numcodecs, multidict, jmespath, frozenlist, dill, async-timeout, aioitertools, yarl, multiprocess, humbug, botocore, aiosignal, s3transfer, pathos, aiohttp, boto3, aiobotocore, aioboto3, deeplake
# Successfully installed aioboto3-11.2.0 aiobotocore-2.5.0 aiohttp-3.8.4 aioitertools-0.11.0 aiosignal-1.3.1 async-timeout-4.0.2 boto3-1.26.76 botocore-1.29.76 deeplake-3.6.4 dill-0.3.6 frozenlist-1.3.3 humbug-0.3.1 jmespath-1.0.1 multidict-6.0.4 multiprocess-0.70.14 numcodecs-0.11.0 pathos-0.3.0 pox-0.3.2 ppft-1.7.6.6 pyjwt-2.7.0 s3transfer-0.6.1 yarl-1.9.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
import deeplake

# %% [markdown]
# Importing dataset

# %%
ds_train = deeplake.load("hub://activeloop/lsp-train")
ds_test = deeplake.load("hub://activeloop/lsp-test")

dataloader_train = ds_train.tensorflow()
dataloader_test = ds_test.tensorflow()
# Out:
# -
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/lsp-train
# \
# hub://activeloop/lsp-train loaded successfully.
# |
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/lsp-test
# -
# hub://activeloop/lsp-test loaded successfully.

# %% [markdown]
# Normalization and Denormalization Functions

# %%
def normalization(keypoints, box):
    keypoints[:,0] = (keypoints[:,0] - box[0])/box[2]
    keypoints[:,1] = (keypoints[:,1] - box[1])/box[3]
    return keypoints

# %%
def denormalization(keypoints,box):
    keypoints[:,0] = (keypoints[:,0]*box[2]) + box[0]
    keypoints[:,1] = (keypoints[:,1]*box[3]) + box[1]
    keypoints[:,0] = np.clip(keypoints[:,0],0,box[2])
    keypoints[:,1] = np.clip(keypoints[:,1],0,box[3])
    return keypoints.astype(np.int32)

# %% [markdown]
# Keypoints Visualization

# %%
def visualize_keypoints(image,keypoints,image_visualized):
    height,width = image_visualized.shape[:2]
    try:
        image = cv2.resize(image.numpy(),(width,height))
    except:
        image = cv2.resize(image,(width,height))
    fig , ax = plt.subplots(1,figsize=(10,10))
    ax.imshow(image)
    ax.scatter(keypoints[:,0],keypoints[:,1])
    for i in range(keypoints.shape[0]):
        ax.annotate(str(i), (keypoints[i,0],keypoints[i,1]),fontsize=10)
    for i in range(0,5):
        ax.plot([keypoints[i,0],keypoints[i+1,0]],[keypoints[i,1],keypoints[i+1,1]],linewidth=5)
    for i in range(6,11):
        ax.plot([keypoints[i,0],keypoints[i+1,0]],[keypoints[i,1],keypoints[i+1,1]],linewidth=5)
    for i in range(12,13):
        ax.plot([keypoints[i,0],keypoints[i+1,0]],[keypoints[i,1],keypoints[i+1,1]],linewidth=5)
    plt.show()

# %% [markdown]
# Trying above function on sample

# %%
batch_iter = iter(dataloader_train)
batch = next(batch_iter)

# %%
image = batch["images"]
keypoints = batch["keypoints"]
image_visualized = batch["images_visualized"]

# Visualize the keypoints
visualize_keypoints(image,keypoints,image_visualized)

# %% [markdown]
# Preparing training set

# %%
images = []
keypoints_array = []


for batch in dataloader_train:
    image = batch["images"]
    keypoints = batch["keypoints"].numpy().astype(np.float32)
    keypoints = keypoints[:,0:2]
    image_visualized = batch["images_visualized"].numpy()
    height,width = image_visualized.shape[:2]
    keypoints = normalization(keypoints,(width/2,height/2,width,height))
    image = cv2.resize(image.numpy(),(220,220)).astype(np.float32)/255.0
    images.append(image)
    keypoints_array.append(keypoints)


for batch in dataloader_test:
    image = batch["images"]
    keypoints = batch["keypoints"].numpy().astype(np.float32)
    keypoints = keypoints[:,0:2]
    image_visualized = batch["images_visualized"].numpy()
    height,width = image_visualized.shape[:2]
    keypoints = normalization(keypoints,(width/2,height/2,width,height))
    image = cv2.resize(image.numpy(),(220,220)).astype(np.float32)/255.0
    images.append(image)
    keypoints_array.append(keypoints)


images = np.array(images)
keypoints_array = np.array(keypoints_array,dtype=np.float32)

# %% [markdown]
# Model

# %%
def get_model(output = 14*2):
    model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(96,(11,11),strides=(4,4),activation="relu",input_shape=(220,220,3)),
                                        tf.keras.layers.BatchNormalization(),
                                        tf.keras.layers.MaxPool2D((2,2),strides=(2,2)),
                                        tf.keras.layers.Conv2D(256,(5,5),activation="relu",padding="same"),
                                        tf.keras.layers.BatchNormalization(),
                                        tf.keras.layers.MaxPool2D((2,2),strides=(2,2)),
                                        tf.keras.layers.Conv2D(384,(3,3),activation="relu"),
                                        tf.keras.layers.BatchNormalization(),
                                        tf.keras.layers.Conv2D(384,(3,3),activation="relu"),
                                        tf.keras.layers.BatchNormalization(),
                                        tf.keras.layers.Conv2D(256,(3,3),activation="relu"),
                                        tf.keras.layers.BatchNormalization(),
                                        tf.keras.layers.MaxPool2D((2,2)),
                                        tf.keras.layers.Flatten(),
                                        tf.keras.layers.Dense(4096,activation="relu"),
                                        tf.keras.layers.Dropout(0.5),
                                        tf.keras.layers.Dense(4096,activation="relu"),
                                        tf.keras.layers.Dropout(0.5),
                                        tf.keras.layers.Dense(output,activation="linear")])
    return model

# %%
model = get_model()

# %% [markdown]
# Loss Function

# %%
def loss_fn(y_true,y_pred):
    y_pred = tf.reshape(y_pred,(-1,14,2))
    return tf.reduce_sum(tf.square(y_true-y_pred))

# %% [markdown]
# Model compilation

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),loss=loss_fn)

# %%
model.fit(images,keypoints_array,epochs=10,batch_size=32,validation_split=0.1,shuffle=True,verbose=1)
# Out:
# Epoch 1/10
# 57/57 [==============================] - 274s 5s/step - loss: 709.2325 - val_loss: 33.7397
# Epoch 2/10
# 57/57 [==============================] - 259s 5s/step - loss: 131.3118 - val_loss: 30.7715
# Epoch 3/10
# 57/57 [==============================] - 259s 5s/step - loss: 75.9708 - val_loss: 29.3004
# Epoch 4/10
# 57/57 [==============================] - 254s 4s/step - loss: 54.7905 - val_loss: 27.9016
# Epoch 5/10
# 57/57 [==============================] - 261s 5s/step - loss: 42.4470 - val_loss: 26.9499
# Epoch 6/10
# 57/57 [==============================] - 258s 5s/step - loss: 35.6684 - val_loss: 27.1881
# Epoch 7/10
# 57/57 [==============================] - 260s 5s/step - loss: 30.9095 - val_loss: 27.1150
# Epoch 8/10
# 57/57 [==============================] - 253s 4s/step - loss: 27.7018 - val_loss: 27.3267
# Epoch 9/10
# 57/57 [==============================] - 251s 4s/step - loss: 25.5249 - val_loss: 26.4223
# Epoch 10/10
# 57/57 [==============================] - 249s 4s/step - loss: 23.8179 - val_loss: 26.1191

# %%
model.save("deeppose.h5")

# %%
model = tf.keras.models.load_model("deeppose.h5",custom_objects={"loss_fn":loss_fn})

# %% [markdown]
# Getting predictions from model

# %%
def predict(model,image):
    image= cv2.resize(image,(220,220))
    image = np.expand_dims(image,axis=0)
    image = tf.convert_to_tensor(image,dtype=tf.float32)
    pred = model(image)
    pred = tf.reshape(pred,(14,2))
    return pred

# %%
test_iter = iter(dataloader_test)

# %%
img = next(test_iter)["images"].numpy()
img = cv2.resize(img,(220,220))
image = cv2.resize(img,(220,220)).astype(np.float32)/255.0
pred = predict(model,image).numpy()
keypoints = denormalization(pred,(110,110,220,220))
visualize_keypoints(img,keypoints,img)

# %%
#img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#img = cv2.resize(img,(220,220))
#image = cv2.resize(img,(220,220)).astype(np.float32)/255.0
#pred = predict(model,image).numpy()
#keypoints = denormalization(pred,(110,110,220,220))
#visualize_keypoints(img,keypoints,img)

# %% [markdown]
# it predicts the above image well.

# %% [markdown]
# Cascade Model
